# %% [markdown]
# ## BEATLEX: Summarizing and Forecasting Time Series with Patterns
#
# ### Abstract
# Given time-series data such as electrocardiogram (ECG) readings, or motion capture data, how can we succintly summarize the data in a way that robustly identifies patterns that appear repeatedly? How can we then use such a summary to identify anomalies such as abnormal heartbeats, and also forecast future values of the time series? Our main idea is a vocabulary-based approach, which automatically learns a set of common patterns, or ‘beat patterns,’ which are used as building blocks to describe the time series in an intuitive and interpretable way. Our summarization algorithm, BEATLEX (BEAT LEXicons for Summarization) is: 1) fast and online, requiring linear time in the data size and bounded memory; 2) effective, outperforming competing algorithms in labelling accuracy by 5.3 times, and forecasting accuracy by 1.8 times; 3) principled and parameterfree, as it is based on the Minimum Description Length principle of summarizing the data by compressing it using as few bits as possible, and automatically tunes all its parameters; 4) general: it applies to any domain of time series data, and can make use of multidimensional (i.e. coevolving) time series.

# %% [markdown]
# You can configure the backend to use GPU or CPU only. \
# Default is using backend cpu.

# %%
import sys
sys.path.append("C:/Users/bailean/Documents/Bitbucket-Projects/spartan2")


import spartan as st

# %% [markdown]
# ```loadTensor``` function automatically read data from file and ```toDTensor``` function extract time and value separately from the tensor.<br/>```Timeseries``` class is designed to construct time tensor.

# %%
kwargs = {'usecols': [0,1, 2]}
time, value = st.loadTensor(path = "inputData/ecg_timeseries_small.zip", col_types = [float, float, float], sep=' ', **kwargs).toDTensor(hastticks=True)
time_series = st.Timeseries(value, time)
st.plot_timeseries(time_series.cut(0, 4000))

# %%
print(f"time series {time_series}, type {type(time_series)}")
# Out:
#          Time  dim_0  dim_1
# 0       0.000 -0.145 -0.065
# 1       0.003 -0.145 -0.065
# 2       0.006 -0.145 -0.065
# 3       0.008 -0.145 -0.065
# 4       0.011 -0.145 -0.065
# ...       ...    ...    ...
# 35995  99.986 -0.350 -0.160
# 35996  99.989 -0.335 -0.150
# 35997  99.992 -0.325 -0.145
# 35998  99.994 -0.325 -0.155
# 35999  99.997 -0.330 -0.165
#
# [36000 rows x 3 columns]
# time series
#             Time Series Object
#             Dimension Size: 2
#             Length: 36000
#             Time Length: 99.997
#             Frequency: 360.011
#             Start Timestamp: 0.0
#             Labels: dim_0, dim_1
#         , type <class 'spartan.tensor.timeseries.Timeseries'>

# %% [markdown]
# ### Run Beatlex from specific task

# %%
ss_task = st.Summarization.create(time_series, st.SumPolicy.BeatLex, 'my_beatlex_model')

# %%
result = ss_task.run()
# Out:
# init at 298
#
# ========segment 2 at 299 598
# cluster cost [0.00637887]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 294
# cluster 0
#
# ========segment 3 at 593 892
# cluster cost [0.00286804]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 0
#
# ========segment 4 at 885 1184
# cluster cost [0.00174464]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 5 at 1169 1468
# cluster cost [0.0025184]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 6 at 1453 1752
# cluster cost [0.00166487]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 7 at 1737 2036
# cluster cost [0.00471445]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 0
#
# ========segment 8 at 2032 2331
# cluster cost [0.01229837]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# new_cluster
# best_place: [294, 0, 297]
# best_S1: 294
# new cluster starts 2032 ends 2326
#
# ========segment 9 at 2327 2626
# cluster cost [0.00213583 0.04123544]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 298
# cluster 0
#
# ========segment 10 at 2625 2924
# cluster cost [0.01474311 0.03873253]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# new_cluster
# best_place: [250, 2, 291]
# best_S1: 250
# new cluster starts 2625 ends 2875
#
# ========segment 11 at 2876 3175
# cluster cost [0.04005677 0.04485458 0.00110664]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 2
#
# ========segment 12 at 3168 3467
# cluster cost [0.03750308 0.0418818  0.00150407]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 2
#
# ========segment 13 at 3453 3752
# cluster cost [0.03714574 0.04339458 0.00285669]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 277
# cluster 2
#
# ========segment 14 at 3730 4029
# cluster cost [0.04092389 0.04570234 0.01550549]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# new_cluster
# best_place: [179, 3, 251]
# best_S1: 179
# new cluster starts 3730 ends 3909
#
# ========segment 15 at 3910 4209
# cluster cost [0.03089441 0.03108606 0.02521358 0.0229622 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 252
# new_cluster
# best_place: [181, 0, 299]
# best_S1: 181
# new cluster starts 3910 ends 4091
#
# ========segment 16 at 4092 4391
# cluster cost [0.04770484 0.05350723 0.00156688 0.04977826 0.03054629]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 249
# cluster 2
#
# ========segment 17 at 4341 4640
# cluster cost [0.03754083 0.0449389  0.00434389 0.04230792 0.02300814]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 2
#
# ========segment 18 at 4636 4935
# cluster cost [0.04319094 0.05103737 0.00561448 0.04547839 0.02549047]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 2
#
# ========segment 19 at 4935 5234
# cluster cost [0.04129695 0.04877576 0.0011706  0.04318155 0.02544046]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 2
#
# ========segment 20 at 5231 5530
# cluster cost [0.03873734 0.04549773 0.00067647 0.04053907 0.02358291]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 21 at 5517 5816
# cluster cost [0.0530596  0.06213641 0.0063138  0.05688201 0.03650767]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 22 at 5804 6103
# cluster cost [0.04637964 0.05581162 0.00343226 0.04785325 0.02733961]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 2
#
# ========segment 23 at 6089 6388
# cluster cost [0.04650714 0.05463505 0.00167537 0.04930342 0.03128209]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 2
#
# ========segment 24 at 6385 6684
# cluster cost [0.06258629 0.0675506  0.06015982 0.00102302 0.03159372]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 189
# cluster 3
#
# ========segment 25 at 6574 6873
# cluster cost [0.03780656 0.04694096 0.03568439 0.03730406 0.00275173]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 188
# cluster 4
#
# ========segment 26 at 6762 7061
# cluster cost [0.05157573 0.05891013 0.00268444 0.05390095 0.02866689]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 2
#
# ========segment 27 at 6994 7293
# cluster cost [0.04273987 0.04986738 0.00110181 0.0416106  0.02527077]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 282
# cluster 2
#
# ========segment 28 at 7276 7575
# cluster cost [0.05534996 0.06191914 0.00682542 0.05637481 0.0415142 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 29 at 7562 7861
# cluster cost [0.04042494 0.04804708 0.00056197 0.04352249 0.02462927]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 278
# cluster 2
#
# ========segment 30 at 7840 8139
# cluster cost [0.04335617 0.05159351 0.00222473 0.04477249 0.02454622]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 31 at 8123 8422
# cluster cost [0.04700896 0.05240853 0.00317278 0.04961791 0.03146191]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 32 at 8416 8715
# cluster cost [0.04389304 0.04858699 0.00440267 0.04817519 0.02824036]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 33 at 8709 9008
# cluster cost [0.04400865 0.04951669 0.00800153 0.05103597 0.02636536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 298
# new_cluster
# best_place: [235, 4, 181]
# best_S1: 235
# new cluster starts 8709 ends 8944
#
# ========segment 34 at 8945 9244
# cluster cost [0.08262812 0.08342005 0.05855841 0.04296855 0.00990353 0.04155378]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# new_cluster
# best_place: [299, 3, 233]
# best_S1: 299
# new cluster starts 8945 ends 9244
#
# ========segment 35 at 9245 9544
# cluster cost [0.07551902 0.08028542 0.06996234 0.00555953 0.04306384 0.06890983
#  0.07324215]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 234
# cluster 3
#
# ========segment 36 at 9479 9778
# cluster cost [0.04613715 0.0524701  0.04448496 0.04360405 0.00249699 0.03881588
#  0.04049814]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 181
# cluster 4
#
# ========segment 37 at 9660 9959
# cluster cost [0.00162545 0.04289793 0.04087156 0.04787256 0.02167034 0.04450028
#  0.05012551]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 272
# cluster 0
#
# ========segment 38 at 9932 10231
# cluster cost [0.04716584 0.05353596 0.00344097 0.05380688 0.02627719 0.04299523
#  0.05119338]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# cluster 2
#
# ========segment 39 at 10168 10467
# cluster cost [0.06521498 0.0704699  0.05679155 0.06091322 0.02985032 0.02518753
#  0.0022086 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 218
# cluster 6
#
# ========segment 40 at 10386 10685
# cluster cost [0.06116109 0.06863051 0.05183101 0.00163346 0.03165319 0.05365223
#  0.05542995]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 252
# cluster 3
#
# ========segment 41 at 10638 10937
# cluster cost [0.0436486  0.05276283 0.04198668 0.04344683 0.00229159 0.03537643
#  0.03347906]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 192
# cluster 4
#
# ========segment 42 at 10830 11129
# cluster cost [0.05590524 0.06319654 0.0026752  0.06168223 0.03317933 0.0512708
#  0.05749294]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# cluster 2
#
# ========segment 43 at 11065 11364
# cluster cost [0.05529875 0.05895707 0.04822653 0.05455431 0.02513086 0.02328563
#  0.00139871]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 230
# cluster 6
#
# ========segment 44 at 11295 11594
# cluster cost [0.0468402  0.05076163 0.04151784 0.04353773 0.02225094 0.02020612
#  0.00161636]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 289
# cluster 6
#
# ========segment 45 at 11584 11883
# cluster cost [0.06486963 0.07224995 0.06005532 0.00286239 0.03973331 0.06494954
#  0.0653195 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 3
#
# ========segment 46 at 11828 12127
# cluster cost [0.03876628 0.04477535 0.04131589 0.04225672 0.00157754 0.04008118
#  0.04014187]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 47 at 12008 12307
# cluster cost [0.00174908 0.03836179 0.03880107 0.04991638 0.02185924 0.04131339
#  0.04605185]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 48 at 12288 12587
# cluster cost [0.05743208 0.06391137 0.0064664  0.06678084 0.0354451  0.04791358
#  0.05518299]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 2
#
# ========segment 49 at 12520 12819
# cluster cost [0.0664154  0.07002833 0.05627697 0.06180634 0.03102659 0.01967083
#  0.00141167]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 6
#
# ========segment 50 at 12749 13048
# cluster cost [0.06717701 0.07523276 0.05510983 0.00244028 0.03235602 0.05415711
#  0.05681731]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 248
# cluster 3
#
# ========segment 51 at 12997 13296
# cluster cost [0.045768   0.05472728 0.04356552 0.04484952 0.00218497 0.03603783
#  0.03530315]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 192
# cluster 4
#
# ========segment 52 at 13189 13488
# cluster cost [0.00314449 0.04136129 0.03963204 0.04845355 0.02335921 0.04357145
#  0.04509921]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 0
#
# ========segment 53 at 13488 13787
# cluster cost [0.00229463 0.03767749 0.0386129  0.04451666 0.01919302 0.04299578
#  0.04428245]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 0
#
# ========segment 54 at 13784 14083
# cluster cost [0.00721499 0.04559629 0.05392753 0.06009376 0.03767249 0.06200125
#  0.06943674]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 55 at 14064 14363
# cluster cost [0.01081691 0.04703348 0.05835193 0.06782537 0.046113   0.0677208
#  0.07738208]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 289
# new_cluster
# best_place: [190, 7, 291]
# best_S1: 190
# new cluster starts 14064 ends 14254
#
# ========segment 56 at 14255 14554
# cluster cost [0.04864013 0.04035107 0.0470582  0.05845849 0.04087892 0.05146498
#  0.06130658 0.00454105]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 7
#
# ========segment 57 at 14547 14846
# cluster cost [0.04378213 0.04152588 0.04281876 0.04821872 0.02495296 0.00294271
#  0.02237674 0.05273634]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 271
# cluster 5
#
# ========segment 58 at 14818 15117
# cluster cost [0.05632252 0.05939312 0.0570095  0.00507424 0.0348941  0.05304486
#  0.06106935 0.05693025]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 240
# cluster 3
#
# ========segment 59 at 15058 15357
# cluster cost [0.03713004 0.04268324 0.04316512 0.04009316 0.00268277 0.03691828
#  0.04315129 0.05357121]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# cluster 4
#
# ========segment 60 at 15240 15539
# cluster cost [0.0007884  0.03999221 0.04105158 0.05178163 0.02628487 0.04518189
#  0.05184911 0.0541743 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 0
#
# ========segment 61 at 15532 15831
# cluster cost [0.04227339 0.04837755 0.00119699 0.05291761 0.02706978 0.04321609
#  0.05061388 0.05573778]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 245
# cluster 2
#
# ========segment 62 at 15777 16076
# cluster cost [0.03857871 0.04425879 0.00111515 0.04299874 0.02206321 0.03703757
#  0.03880359 0.05659593]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 63 at 16070 16369
# cluster cost [0.05311872 0.05944183 0.00325882 0.05957248 0.03838919 0.05178845
#  0.05578114 0.06561771]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 64 at 16353 16652
# cluster cost [0.0510897  0.05671915 0.00247505 0.05756578 0.03698386 0.04857054
#  0.05392762 0.06008591]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 282
# cluster 2
#
# ========segment 65 at 16635 16934
# cluster cost [0.05416915 0.05684844 0.04750622 0.05504045 0.02580631 0.02153559
#  0.00155325 0.07006902]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 224
# cluster 6
#
# ========segment 66 at 16859 17158
# cluster cost [0.05864355 0.06773506 0.04650804 0.00333185 0.02287757 0.04649776
#  0.04819084 0.06854182]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 246
# cluster 3
#
# ========segment 67 at 17105 17404
# cluster cost [0.03844783 0.04669225 0.04030973 0.03799595 0.000452   0.03744578
#  0.03675357 0.05827672]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 187
# cluster 4
#
# ========segment 68 at 17292 17591
# cluster cost [0.00156021 0.0436013  0.04296662 0.05162914 0.02792921 0.04940551
#  0.05226648 0.06023874]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 0
#
# ========segment 69 at 17580 17879
# cluster cost [0.00603986 0.05352567 0.04914216 0.06506639 0.0412082  0.05710806
#  0.06084608 0.06519508]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 0
#
# ========segment 70 at 17879 18178
# cluster cost [0.04800778 0.05544627 0.00238799 0.05334181 0.02672791 0.04361679
#  0.04628575 0.06780434]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 238
# cluster 2
#
# ========segment 71 at 18117 18416
# cluster cost [0.0442527  0.05081237 0.00182214 0.04591207 0.02519824 0.04092509
#  0.04148612 0.06176366]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 2
#
# ========segment 72 at 18397 18696
# cluster cost [0.04245988 0.04864399 0.0012033  0.04752247 0.02683723 0.03954104
#  0.04197087 0.05848137]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 73 at 18684 18983
# cluster cost [0.06122259 0.06310285 0.0541473  0.05968136 0.03105055 0.02553643
#  0.00259748 0.0736307 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 215
# cluster 6
#
# ========segment 74 at 18899 19198
# cluster cost [0.05190583 0.0568825  0.04233395 0.04742419 0.02369522 0.02437544
#  0.00193732 0.07784007]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 6
#
# ========segment 75 at 19184 19483
# cluster cost [0.06473723 0.07375692 0.05357464 0.00268427 0.0319704  0.05774148
#  0.05825006 0.07380349]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 251
# cluster 3
#
# ========segment 76 at 19435 19734
# cluster cost [0.03690499 0.04735601 0.03942045 0.03994883 0.00186082 0.04307644
#  0.03901183 0.06472426]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 4
#
# ========segment 77 at 19620 19919
# cluster cost [0.0039792  0.04919763 0.04623961 0.0596832  0.03509568 0.05639581
#  0.05883898 0.06330092]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 0
#
# ========segment 78 at 19915 20214
# cluster cost [0.0439027  0.05075379 0.00229224 0.05249742 0.02876552 0.04820415
#  0.05393468 0.05800681]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 2
#
# ========segment 79 at 20159 20458
# cluster cost [0.03973535 0.04618414 0.00318915 0.04547924 0.02636172 0.04630673
#  0.0469633  0.05530671]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 80 at 20442 20741
# cluster cost [0.06797722 0.06178623 0.06244825 0.07051117 0.05090261 0.07386983
#  0.08211733 0.00934667]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# new_cluster
# best_place: [291, 8, 282]
# best_S1: 291
# new cluster starts 20442 ends 20733
#
# ========segment 81 at 20734 21033
# cluster cost [0.05452058 0.05694629 0.05248244 0.06768045 0.04906803 0.06594112
#  0.07685095 0.04815942 0.00150115]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 8
#
# ========segment 82 at 21017 21316
# cluster cost [0.04320538 0.04605634 0.04233838 0.05701056 0.03719333 0.05130408
#  0.0592688  0.04410989 0.00238663]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 294
# cluster 8
#
# ========segment 83 at 21311 21610
# cluster cost [0.04629464 0.05037012 0.04144617 0.05478411 0.03631578 0.05484529
#  0.05926119 0.05142137 0.00253282]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 8
#
# ========segment 84 at 21603 21902
# cluster cost [0.06598684 0.0606242  0.06026357 0.06881639 0.05187991 0.07164799
#  0.07998157 0.01080025 0.04847264]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 250
# new_cluster
# best_place: [236, 9, 299]
# best_S1: 236
# new cluster starts 21603 ends 21839
#
# ========segment 85 at 21840 22139
# cluster cost [0.04811737 0.04679406 0.04694157 0.05815085 0.04064564 0.02670132
#  0.04591331 0.05109544 0.03819958 0.00563583]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 9
#
# ========segment 86 at 22139 22438
# cluster cost [0.04024854 0.04037991 0.03507358 0.04615337 0.02611321 0.0200229
#  0.03556485 0.05187315 0.04124758 0.00665949]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 9
#
# ========segment 87 at 22432 22731
# cluster cost [0.04714399 0.05111455 0.04160481 0.04772961 0.02550197 0.0286874
#  0.00547586 0.0687727  0.05785101 0.04620282]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 274
# cluster 6
#
# ========segment 88 at 22706 23005
# cluster cost [0.06212973 0.06789814 0.05557146 0.0063104  0.03342691 0.06272618
#  0.05806612 0.07918837 0.06582535 0.05548791]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 222
# cluster 3
#
# ========segment 89 at 22928 23227
# cluster cost [0.04497103 0.05732507 0.0417101  0.04486416 0.00386938 0.04921098
#  0.04050855 0.07143677 0.06474825 0.05083414]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 90 at 23108 23407
# cluster cost [0.05395919 0.06195935 0.00336505 0.05692361 0.03081105 0.0560512
#  0.05801727 0.0725729  0.05960348 0.0535453 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 226
# cluster 2
#
# ========segment 91 at 23334 23633
# cluster cost [0.0470769  0.05565091 0.00486072 0.04947777 0.02753075 0.04776463
#  0.04123164 0.07260332 0.05505426 0.05016832]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 290
# cluster 2
#
# ========segment 92 at 23624 23923
# cluster cost [0.07527861 0.08322743 0.06659906 0.00585089 0.03649236 0.07642573
#  0.06917161 0.09117867 0.08284006 0.06945536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 3
#
# ========segment 93 at 23804 24103
# cluster cost [0.04147597 0.05387054 0.04022861 0.04193397 0.00266308 0.04698119
#  0.03849106 0.0724726  0.06246027 0.04985566]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 4
#
# ========segment 94 at 23989 24288
# cluster cost [0.00403318 0.05065892 0.04509247 0.05537329 0.03126458 0.05794807
#  0.05633925 0.06860779 0.05128601 0.05191469]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 0
#
# ========segment 95 at 24275 24574
# cluster cost [0.04768712 0.05534595 0.0027107  0.05453209 0.03110368 0.05013527
#  0.05411941 0.0613098  0.05046778 0.04610036]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 241
# cluster 2
#
# ========segment 96 at 24516 24815
# cluster cost [0.06564462 0.07222347 0.05409028 0.06206259 0.03176842 0.03308141
#  0.0036403  0.08821466 0.08598646 0.06446781]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 213
# cluster 6
#
# ========segment 97 at 24729 25028
# cluster cost [0.08786522 0.09638739 0.07242878 0.00558309 0.04727448 0.07743211
#  0.07610546 0.09919999 0.09743077 0.07702779]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 3
#
# ========segment 98 at 24961 25260
# cluster cost [0.0485284  0.06032528 0.04310117 0.04539576 0.00171164 0.0439242
#  0.03679421 0.07482508 0.07764224 0.05917928]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 99 at 25141 25440
# cluster cost [0.05293078 0.0598826  0.00106416 0.05761665 0.03167277 0.05357764
#  0.05630204 0.07112092 0.0582378  0.05865796]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 227
# cluster 2
#
# ========segment 100 at 25368 25667
# cluster cost [0.04199019 0.04872417 0.00125458 0.04515224 0.02351043 0.03993607
#  0.03764566 0.06233294 0.05329797 0.04718164]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 101 at 25655 25954
# cluster cost [0.04666412 0.0534503  0.00240871 0.04723269 0.02792474 0.04648574
#  0.04317558 0.06628131 0.04919787 0.04983932]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 2
#
# ========segment 102 at 25950 26249
# cluster cost [0.07214884 0.07470541 0.06809534 0.00209059 0.04183793 0.07420255
#  0.07230659 0.08430402 0.07684981 0.06847625]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 3
#
# ========segment 103 at 26135 26434
# cluster cost [0.04045179 0.05093917 0.03773957 0.0405942  0.00107649 0.04062464
#  0.03430312 0.06627174 0.06205744 0.04800129]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 187
# cluster 4
#
# ========segment 104 at 26322 26621
# cluster cost [0.0535922  0.06074255 0.00201478 0.05765304 0.03134797 0.04975992
#  0.05216704 0.07084533 0.06098671 0.05571767]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# cluster 2
#
# ========segment 105 at 26557 26856
# cluster cost [0.06716538 0.07352846 0.05449837 0.06221987 0.03064883 0.03187013
#  0.00281808 0.09103862 0.09182657 0.06875038]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 217
# cluster 6
#
# ========segment 106 at 26774 27073
# cluster cost [0.08116171 0.08430261 0.06197408 0.00161636 0.03074061 0.05916722
#  0.06125763 0.07929062 0.09289912 0.06576528]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 225
# cluster 3
#
# ========segment 107 at 26999 27298
# cluster cost [0.04103436 0.04919    0.04082604 0.04083975 0.00074792 0.04111926
#  0.04004125 0.06321523 0.06556146 0.05314027]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 108 at 27179 27478
# cluster cost [0.00217599 0.04717067 0.04819169 0.05689084 0.03314359 0.05543261
#  0.06100875 0.05961795 0.04975621 0.05190311]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 109 at 27459 27758
# cluster cost [0.04747149 0.04961143 0.04734108 0.05617032 0.03509292 0.05176073
#  0.06105704 0.04645785 0.00209259 0.04122431]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 257
# cluster 8
#
# ========segment 110 at 27716 28015
# cluster cost [0.04621317 0.05197949 0.00196981 0.05190383 0.03063653 0.04516746
#  0.04569963 0.06215752 0.04899758 0.05091572]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 111 at 28003 28302
# cluster cost [0.04674601 0.05198888 0.00235897 0.05202221 0.03185456 0.04306483
#  0.04536502 0.06066698 0.04999568 0.05208785]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 2
#
# ========segment 112 at 28302 28601
# cluster cost [0.06344373 0.06552725 0.05428575 0.05951377 0.03321899 0.02190485
#  0.00165035 0.07674479 0.07652745 0.05025617]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 233
# cluster 6
#
# ========segment 113 at 28535 28834
# cluster cost [0.04374905 0.04393915 0.0363124  0.04129346 0.02084494 0.01593583
#  0.00160367 0.06178164 0.05233604 0.04067505]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 6
#
# ========segment 114 at 28831 29130
# cluster cost [0.05135114 0.05622496 0.04053337 0.04655276 0.02323933 0.02398728
#  0.00199919 0.07779081 0.06573652 0.05687827]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 6
#
# ========segment 115 at 29118 29417
# cluster cost [0.05412612 0.05829906 0.04367116 0.04760037 0.02532701 0.01981455
#  0.00144651 0.07418168 0.06593586 0.04737023]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 6
#
# ========segment 116 at 29398 29697
# cluster cost [0.07657741 0.08286283 0.06549038 0.00315022 0.04040615 0.0708936
#  0.06851941 0.08580233 0.08166401 0.0673624 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 3
#
# ========segment 117 at 29627 29926
# cluster cost [0.04410285 0.05464132 0.03993151 0.04192025 0.00169844 0.04623039
#  0.03843381 0.06895443 0.06274981 0.04960051]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 118 at 29807 30106
# cluster cost [0.05963639 0.06829168 0.00372703 0.06383878 0.03723738 0.05930331
#  0.06064076 0.07627213 0.06006814 0.05739123]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# cluster 2
#
# ========segment 119 at 30043 30342
# cluster cost [0.06045715 0.06679465 0.0488272  0.05580115 0.02965183 0.03061715
#  0.00439247 0.0863797  0.07087973 0.0524775 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 243
# cluster 6
#
# ========segment 120 at 30286 30585
# cluster cost [0.06572443 0.07721951 0.05259281 0.00456303 0.03236057 0.06086249
#  0.05526439 0.08406986 0.07341984 0.05660082]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 248
# cluster 3
#
# ========segment 121 at 30534 30833
# cluster cost [0.05469347 0.06783764 0.04471358 0.04604959 0.00386057 0.05030941
#  0.03782565 0.08102592 0.07835884 0.05884073]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# cluster 4
#
# ========segment 122 at 30716 31015
# cluster cost [0.05469438 0.06304222 0.0030178  0.05487424 0.02920992 0.054261
#  0.0542759  0.07385634 0.06352687 0.05484224]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 233
# cluster 2
#
# ========segment 123 at 30949 31248
# cluster cost [0.04324927 0.05151565 0.00212013 0.04358414 0.0237815  0.0458555
#  0.04120243 0.06623695 0.05017798 0.04805996]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 124 at 31235 31534
# cluster cost [0.04452581 0.05146709 0.00228988 0.05004832 0.03127942 0.04955521
#  0.0490894  0.05792817 0.04437185 0.0438105 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 125 at 31518 31817
# cluster cost [0.04599146 0.05295308 0.001916   0.05203774 0.03312108 0.04928108
#  0.0493567  0.05910676 0.04249553 0.04620784]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 2
#
# ========segment 126 at 31806 32105
# cluster cost [0.04419648 0.05081246 0.00172712 0.04938542 0.02773095 0.04153218
#  0.04077541 0.06237637 0.05002597 0.04869519]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 2
#
# ========segment 127 at 32098 32397
# cluster cost [0.06762873 0.07240761 0.05541521 0.06112828 0.03232997 0.02779873
#  0.0012874  0.09043396 0.08388602 0.05919513]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 230
# cluster 6
#
# ========segment 128 at 32328 32627
# cluster cost [0.07535953 0.08377264 0.06434174 0.0040894  0.04386952 0.07035012
#  0.07019913 0.08763748 0.08242577 0.06982347]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 249
# cluster 3
#
# ========segment 129 at 32577 32876
# cluster cost [0.04341684 0.05314886 0.03934676 0.04184498 0.00088832 0.0379831
#  0.03342733 0.06902538 0.06917833 0.05496708]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 186
# cluster 4
#
# ========segment 130 at 32763 33062
# cluster cost [0.05579409 0.06254177 0.00137714 0.06059955 0.03536115 0.05256159
#  0.05416151 0.07176982 0.06014318 0.05870562]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 243
# cluster 2
#
# ========segment 131 at 33006 33305
# cluster cost [0.06898283 0.07343361 0.05827292 0.0636199  0.0336456  0.02543713
#  0.00103376 0.08860832 0.08831514 0.05998898]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 225
# cluster 6
#
# ========segment 132 at 33231 33530
# cluster cost [0.04954902 0.0528029  0.04280531 0.0439149  0.02125465 0.0246413
#  0.00196498 0.07183673 0.06278116 0.05028182]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 276
# cluster 6
#
# ========segment 133 at 33507 33806
# cluster cost [0.05847118 0.05504683 0.05376302 0.05839077 0.03980869 0.0306605
#  0.04857087 0.06862784 0.05496835 0.00550669]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 9
#
# ========segment 134 at 33803 34102
# cluster cost [0.04575107 0.04247274 0.04291065 0.04973056 0.0305865  0.02028441
#  0.03938239 0.05487785 0.04220577 0.00265625]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 9
#
# ========segment 135 at 34091 34390
# cluster cost [0.04425654 0.04476895 0.03879314 0.0452748  0.02399574 0.01808022
#  0.00244198 0.06076018 0.05122117 0.03662072]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 6
#
# ========segment 136 at 34378 34677
# cluster cost [0.06551348 0.07144006 0.05953764 0.00361687 0.03658768 0.06168901
#  0.06495508 0.06779011 0.069967   0.05484947]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 3
#
# ========segment 137 at 34622 34921
# cluster cost [0.03424392 0.03937072 0.04246026 0.04037081 0.00578172 0.04513998
#  0.05040523 0.05391854 0.04417991 0.04365363]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 181
# cluster 4
#
# ========segment 138 at 34803 35102
# cluster cost [0.05582747 0.05819291 0.05577841 0.06524912 0.04146103 0.06069105
#  0.07443046 0.05468093 0.00165636 0.05123619]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 247
# cluster 8
#
# ========segment 139 at 35050 35349
# cluster cost [0.05622244 0.05249072 0.0514349  0.05901599 0.03565618 0.02387055
#  0.05092903 0.05859777 0.05140592 0.00189536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 9
#
# ========segment 140 at 35279 35578
# cluster cost [0.04207839 0.04139321 0.03694352 0.04466305 0.02316275 0.01614702
#  0.0323991  0.05186871 0.04396102 0.00319976]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 9
#
# ========segment 141 at 35566 35865
# cluster cost [0.05311776 0.05035623 0.05119278 0.05856671 0.03872747 0.02701469
#  0.04920258 0.05324273 0.04791296 0.00196419]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 281
# cluster 9
#
# ========segment 142 at 35847 36000
# C:/Users/bailean/Documents/Bitbucket-Projects/spartan2\spartan\model\beatlex\Beatlex.py:73: RuntimeWarning: All-NaN slice encountered
#   best_cost = np.nanmin(ave_costs)
# Sequence End Reached
# best prefix found 9 nan 0.0019433397295321652
# ending with prefix [8]

# %% [markdown]
# ### Run Beatlex as a single model

# %%
beatlex = st.BeatLex(time_series)

# %%
result = beatlex.run()
# Out:
# init at 298
#
# ========segment 2 at 299 598
# cluster cost [0.00637887]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 294
# cluster 0
#
# ========segment 3 at 593 892
# cluster cost [0.00286804]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 0
#
# ========segment 4 at 885 1184
# cluster cost [0.00174464]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 5 at 1169 1468
# cluster cost [0.0025184]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 6 at 1453 1752
# cluster cost [0.00166487]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 284
# cluster 0
#
# ========segment 7 at 1737 2036
# cluster cost [0.00471445]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 0
#
# ========segment 8 at 2032 2331
# cluster cost [0.01229837]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# new_cluster
# best_place: [294, 0, 297]
# best_S1: 294
# new cluster starts 2032 ends 2326
#
# ========segment 9 at 2327 2626
# cluster cost [0.00213583 0.04123544]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 298
# cluster 0
#
# ========segment 10 at 2625 2924
# cluster cost [0.01474311 0.03873253]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# new_cluster
# best_place: [250, 2, 291]
# best_S1: 250
# new cluster starts 2625 ends 2875
#
# ========segment 11 at 2876 3175
# cluster cost [0.04005677 0.04485458 0.00110664]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 2
#
# ========segment 12 at 3168 3467
# cluster cost [0.03750308 0.0418818  0.00150407]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 2
#
# ========segment 13 at 3453 3752
# cluster cost [0.03714574 0.04339458 0.00285669]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 277
# cluster 2
#
# ========segment 14 at 3730 4029
# cluster cost [0.04092389 0.04570234 0.01550549]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# new_cluster
# best_place: [179, 3, 251]
# best_S1: 179
# new cluster starts 3730 ends 3909
#
# ========segment 15 at 3910 4209
# cluster cost [0.03089441 0.03108606 0.02521358 0.0229622 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 252
# new_cluster
# best_place: [181, 0, 299]
# best_S1: 181
# new cluster starts 3910 ends 4091
#
# ========segment 16 at 4092 4391
# cluster cost [0.04770484 0.05350723 0.00156688 0.04977826 0.03054629]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 249
# cluster 2
#
# ========segment 17 at 4341 4640
# cluster cost [0.03754083 0.0449389  0.00434389 0.04230792 0.02300814]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 2
#
# ========segment 18 at 4636 4935
# cluster cost [0.04319094 0.05103737 0.00561448 0.04547839 0.02549047]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 2
#
# ========segment 19 at 4935 5234
# cluster cost [0.04129695 0.04877576 0.0011706  0.04318155 0.02544046]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 2
#
# ========segment 20 at 5231 5530
# cluster cost [0.03873734 0.04549773 0.00067647 0.04053907 0.02358291]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 21 at 5517 5816
# cluster cost [0.0530596  0.06213641 0.0063138  0.05688201 0.03650767]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 22 at 5804 6103
# cluster cost [0.04637964 0.05581162 0.00343226 0.04785325 0.02733961]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 2
#
# ========segment 23 at 6089 6388
# cluster cost [0.04650714 0.05463505 0.00167537 0.04930342 0.03128209]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 2
#
# ========segment 24 at 6385 6684
# cluster cost [0.06258629 0.0675506  0.06015982 0.00102302 0.03159372]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 189
# cluster 3
#
# ========segment 25 at 6574 6873
# cluster cost [0.03780656 0.04694096 0.03568439 0.03730406 0.00275173]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 188
# cluster 4
#
# ========segment 26 at 6762 7061
# cluster cost [0.05157573 0.05891013 0.00268444 0.05390095 0.02866689]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 2
#
# ========segment 27 at 6994 7293
# cluster cost [0.04273987 0.04986738 0.00110181 0.0416106  0.02527077]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 282
# cluster 2
#
# ========segment 28 at 7276 7575
# cluster cost [0.05534996 0.06191914 0.00682542 0.05637481 0.0415142 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 29 at 7562 7861
# cluster cost [0.04042494 0.04804708 0.00056197 0.04352249 0.02462927]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 278
# cluster 2
#
# ========segment 30 at 7840 8139
# cluster cost [0.04335617 0.05159351 0.00222473 0.04477249 0.02454622]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 31 at 8123 8422
# cluster cost [0.04700896 0.05240853 0.00317278 0.04961791 0.03146191]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 32 at 8416 8715
# cluster cost [0.04389304 0.04858699 0.00440267 0.04817519 0.02824036]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 33 at 8709 9008
# cluster cost [0.04400865 0.04951669 0.00800153 0.05103597 0.02636536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 298
# new_cluster
# best_place: [235, 4, 181]
# best_S1: 235
# new cluster starts 8709 ends 8944
#
# ========segment 34 at 8945 9244
# cluster cost [0.08262812 0.08342005 0.05855841 0.04296855 0.00990353 0.04155378]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# new_cluster
# best_place: [299, 3, 233]
# best_S1: 299
# new cluster starts 8945 ends 9244
#
# ========segment 35 at 9245 9544
# cluster cost [0.07551902 0.08028542 0.06996234 0.00555953 0.04306384 0.06890983
#  0.07324215]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 234
# cluster 3
#
# ========segment 36 at 9479 9778
# cluster cost [0.04613715 0.0524701  0.04448496 0.04360405 0.00249699 0.03881588
#  0.04049814]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 181
# cluster 4
#
# ========segment 37 at 9660 9959
# cluster cost [0.00162545 0.04289793 0.04087156 0.04787256 0.02167034 0.04450028
#  0.05012551]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 272
# cluster 0
#
# ========segment 38 at 9932 10231
# cluster cost [0.04716584 0.05353596 0.00344097 0.05380688 0.02627719 0.04299523
#  0.05119338]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# cluster 2
#
# ========segment 39 at 10168 10467
# cluster cost [0.06521498 0.0704699  0.05679155 0.06091322 0.02985032 0.02518753
#  0.0022086 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 218
# cluster 6
#
# ========segment 40 at 10386 10685
# cluster cost [0.06116109 0.06863051 0.05183101 0.00163346 0.03165319 0.05365223
#  0.05542995]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 252
# cluster 3
#
# ========segment 41 at 10638 10937
# cluster cost [0.0436486  0.05276283 0.04198668 0.04344683 0.00229159 0.03537643
#  0.03347906]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 192
# cluster 4
#
# ========segment 42 at 10830 11129
# cluster cost [0.05590524 0.06319654 0.0026752  0.06168223 0.03317933 0.0512708
#  0.05749294]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# cluster 2
#
# ========segment 43 at 11065 11364
# cluster cost [0.05529875 0.05895707 0.04822653 0.05455431 0.02513086 0.02328563
#  0.00139871]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 230
# cluster 6
#
# ========segment 44 at 11295 11594
# cluster cost [0.0468402  0.05076163 0.04151784 0.04353773 0.02225094 0.02020612
#  0.00161636]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 289
# cluster 6
#
# ========segment 45 at 11584 11883
# cluster cost [0.06486963 0.07224995 0.06005532 0.00286239 0.03973331 0.06494954
#  0.0653195 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 3
#
# ========segment 46 at 11828 12127
# cluster cost [0.03876628 0.04477535 0.04131589 0.04225672 0.00157754 0.04008118
#  0.04014187]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 47 at 12008 12307
# cluster cost [0.00174908 0.03836179 0.03880107 0.04991638 0.02185924 0.04131339
#  0.04605185]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 48 at 12288 12587
# cluster cost [0.05743208 0.06391137 0.0064664  0.06678084 0.0354451  0.04791358
#  0.05518299]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 2
#
# ========segment 49 at 12520 12819
# cluster cost [0.0664154  0.07002833 0.05627697 0.06180634 0.03102659 0.01967083
#  0.00141167]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 6
#
# ========segment 50 at 12749 13048
# cluster cost [0.06717701 0.07523276 0.05510983 0.00244028 0.03235602 0.05415711
#  0.05681731]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 248
# cluster 3
#
# ========segment 51 at 12997 13296
# cluster cost [0.045768   0.05472728 0.04356552 0.04484952 0.00218497 0.03603783
#  0.03530315]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 192
# cluster 4
#
# ========segment 52 at 13189 13488
# cluster cost [0.00314449 0.04136129 0.03963204 0.04845355 0.02335921 0.04357145
#  0.04509921]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 0
#
# ========segment 53 at 13488 13787
# cluster cost [0.00229463 0.03767749 0.0386129  0.04451666 0.01919302 0.04299578
#  0.04428245]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 0
#
# ========segment 54 at 13784 14083
# cluster cost [0.00721499 0.04559629 0.05392753 0.06009376 0.03767249 0.06200125
#  0.06943674]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 55 at 14064 14363
# cluster cost [0.01081691 0.04703348 0.05835193 0.06782537 0.046113   0.0677208
#  0.07738208]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 289
# new_cluster
# best_place: [190, 7, 291]
# best_S1: 190
# new cluster starts 14064 ends 14254
#
# ========segment 56 at 14255 14554
# cluster cost [0.04864013 0.04035107 0.0470582  0.05845849 0.04087892 0.05146498
#  0.06130658 0.00454105]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 7
#
# ========segment 57 at 14547 14846
# cluster cost [0.04378213 0.04152588 0.04281876 0.04821872 0.02495296 0.00294271
#  0.02237674 0.05273634]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 271
# cluster 5
#
# ========segment 58 at 14818 15117
# cluster cost [0.05632252 0.05939312 0.0570095  0.00507424 0.0348941  0.05304486
#  0.06106935 0.05693025]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 240
# cluster 3
#
# ========segment 59 at 15058 15357
# cluster cost [0.03713004 0.04268324 0.04316512 0.04009316 0.00268277 0.03691828
#  0.04315129 0.05357121]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# cluster 4
#
# ========segment 60 at 15240 15539
# cluster cost [0.0007884  0.03999221 0.04105158 0.05178163 0.02628487 0.04518189
#  0.05184911 0.0541743 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 0
#
# ========segment 61 at 15532 15831
# cluster cost [0.04227339 0.04837755 0.00119699 0.05291761 0.02706978 0.04321609
#  0.05061388 0.05573778]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 245
# cluster 2
#
# ========segment 62 at 15777 16076
# cluster cost [0.03857871 0.04425879 0.00111515 0.04299874 0.02206321 0.03703757
#  0.03880359 0.05659593]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 2
#
# ========segment 63 at 16070 16369
# cluster cost [0.05311872 0.05944183 0.00325882 0.05957248 0.03838919 0.05178845
#  0.05578114 0.06561771]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 64 at 16353 16652
# cluster cost [0.0510897  0.05671915 0.00247505 0.05756578 0.03698386 0.04857054
#  0.05392762 0.06008591]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 282
# cluster 2
#
# ========segment 65 at 16635 16934
# cluster cost [0.05416915 0.05684844 0.04750622 0.05504045 0.02580631 0.02153559
#  0.00155325 0.07006902]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 224
# cluster 6
#
# ========segment 66 at 16859 17158
# cluster cost [0.05864355 0.06773506 0.04650804 0.00333185 0.02287757 0.04649776
#  0.04819084 0.06854182]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 246
# cluster 3
#
# ========segment 67 at 17105 17404
# cluster cost [0.03844783 0.04669225 0.04030973 0.03799595 0.000452   0.03744578
#  0.03675357 0.05827672]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 187
# cluster 4
#
# ========segment 68 at 17292 17591
# cluster cost [0.00156021 0.0436013  0.04296662 0.05162914 0.02792921 0.04940551
#  0.05226648 0.06023874]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 0
#
# ========segment 69 at 17580 17879
# cluster cost [0.00603986 0.05352567 0.04914216 0.06506639 0.0412082  0.05710806
#  0.06084608 0.06519508]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 0
#
# ========segment 70 at 17879 18178
# cluster cost [0.04800778 0.05544627 0.00238799 0.05334181 0.02672791 0.04361679
#  0.04628575 0.06780434]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 238
# cluster 2
#
# ========segment 71 at 18117 18416
# cluster cost [0.0442527  0.05081237 0.00182214 0.04591207 0.02519824 0.04092509
#  0.04148612 0.06176366]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 2
#
# ========segment 72 at 18397 18696
# cluster cost [0.04245988 0.04864399 0.0012033  0.04752247 0.02683723 0.03954104
#  0.04197087 0.05848137]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 73 at 18684 18983
# cluster cost [0.06122259 0.06310285 0.0541473  0.05968136 0.03105055 0.02553643
#  0.00259748 0.0736307 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 215
# cluster 6
#
# ========segment 74 at 18899 19198
# cluster cost [0.05190583 0.0568825  0.04233395 0.04742419 0.02369522 0.02437544
#  0.00193732 0.07784007]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 285
# cluster 6
#
# ========segment 75 at 19184 19483
# cluster cost [0.06473723 0.07375692 0.05357464 0.00268427 0.0319704  0.05774148
#  0.05825006 0.07380349]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 251
# cluster 3
#
# ========segment 76 at 19435 19734
# cluster cost [0.03690499 0.04735601 0.03942045 0.03994883 0.00186082 0.04307644
#  0.03901183 0.06472426]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 4
#
# ========segment 77 at 19620 19919
# cluster cost [0.0039792  0.04919763 0.04623961 0.0596832  0.03509568 0.05639581
#  0.05883898 0.06330092]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 0
#
# ========segment 78 at 19915 20214
# cluster cost [0.0439027  0.05075379 0.00229224 0.05249742 0.02876552 0.04820415
#  0.05393468 0.05800681]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 2
#
# ========segment 79 at 20159 20458
# cluster cost [0.03973535 0.04618414 0.00318915 0.04547924 0.02636172 0.04630673
#  0.0469633  0.05530671]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 80 at 20442 20741
# cluster cost [0.06797722 0.06178623 0.06244825 0.07051117 0.05090261 0.07386983
#  0.08211733 0.00934667]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# new_cluster
# best_place: [291, 8, 282]
# best_S1: 291
# new cluster starts 20442 ends 20733
#
# ========segment 81 at 20734 21033
# cluster cost [0.05452058 0.05694629 0.05248244 0.06768045 0.04906803 0.06594112
#  0.07685095 0.04815942 0.00150115]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 8
#
# ========segment 82 at 21017 21316
# cluster cost [0.04320538 0.04605634 0.04233838 0.05701056 0.03719333 0.05130408
#  0.0592688  0.04410989 0.00238663]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 294
# cluster 8
#
# ========segment 83 at 21311 21610
# cluster cost [0.04629464 0.05037012 0.04144617 0.05478411 0.03631578 0.05484529
#  0.05926119 0.05142137 0.00253282]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 8
#
# ========segment 84 at 21603 21902
# cluster cost [0.06598684 0.0606242  0.06026357 0.06881639 0.05187991 0.07164799
#  0.07998157 0.01080025 0.04847264]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 250
# new_cluster
# best_place: [236, 9, 299]
# best_S1: 236
# new cluster starts 21603 ends 21839
#
# ========segment 85 at 21840 22139
# cluster cost [0.04811737 0.04679406 0.04694157 0.05815085 0.04064564 0.02670132
#  0.04591331 0.05109544 0.03819958 0.00563583]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 9
#
# ========segment 86 at 22139 22438
# cluster cost [0.04024854 0.04037991 0.03507358 0.04615337 0.02611321 0.0200229
#  0.03556485 0.05187315 0.04124758 0.00665949]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 293
# cluster 9
#
# ========segment 87 at 22432 22731
# cluster cost [0.04714399 0.05111455 0.04160481 0.04772961 0.02550197 0.0286874
#  0.00547586 0.0687727  0.05785101 0.04620282]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 274
# cluster 6
#
# ========segment 88 at 22706 23005
# cluster cost [0.06212973 0.06789814 0.05557146 0.0063104  0.03342691 0.06272618
#  0.05806612 0.07918837 0.06582535 0.05548791]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 222
# cluster 3
#
# ========segment 89 at 22928 23227
# cluster cost [0.04497103 0.05732507 0.0417101  0.04486416 0.00386938 0.04921098
#  0.04050855 0.07143677 0.06474825 0.05083414]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 90 at 23108 23407
# cluster cost [0.05395919 0.06195935 0.00336505 0.05692361 0.03081105 0.0560512
#  0.05801727 0.0725729  0.05960348 0.0535453 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 226
# cluster 2
#
# ========segment 91 at 23334 23633
# cluster cost [0.0470769  0.05565091 0.00486072 0.04947777 0.02753075 0.04776463
#  0.04123164 0.07260332 0.05505426 0.05016832]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 290
# cluster 2
#
# ========segment 92 at 23624 23923
# cluster cost [0.07527861 0.08322743 0.06659906 0.00585089 0.03649236 0.07642573
#  0.06917161 0.09117867 0.08284006 0.06945536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 3
#
# ========segment 93 at 23804 24103
# cluster cost [0.04147597 0.05387054 0.04022861 0.04193397 0.00266308 0.04698119
#  0.03849106 0.0724726  0.06246027 0.04985566]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 4
#
# ========segment 94 at 23989 24288
# cluster cost [0.00403318 0.05065892 0.04509247 0.05537329 0.03126458 0.05794807
#  0.05633925 0.06860779 0.05128601 0.05191469]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 0
#
# ========segment 95 at 24275 24574
# cluster cost [0.04768712 0.05534595 0.0027107  0.05453209 0.03110368 0.05013527
#  0.05411941 0.0613098  0.05046778 0.04610036]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 241
# cluster 2
#
# ========segment 96 at 24516 24815
# cluster cost [0.06564462 0.07222347 0.05409028 0.06206259 0.03176842 0.03308141
#  0.0036403  0.08821466 0.08598646 0.06446781]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 213
# cluster 6
#
# ========segment 97 at 24729 25028
# cluster cost [0.08786522 0.09638739 0.07242878 0.00558309 0.04727448 0.07743211
#  0.07610546 0.09919999 0.09743077 0.07702779]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 232
# cluster 3
#
# ========segment 98 at 24961 25260
# cluster cost [0.0485284  0.06032528 0.04310117 0.04539576 0.00171164 0.0439242
#  0.03679421 0.07482508 0.07764224 0.05917928]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 99 at 25141 25440
# cluster cost [0.05293078 0.0598826  0.00106416 0.05761665 0.03167277 0.05357764
#  0.05630204 0.07112092 0.0582378  0.05865796]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 227
# cluster 2
#
# ========segment 100 at 25368 25667
# cluster cost [0.04199019 0.04872417 0.00125458 0.04515224 0.02351043 0.03993607
#  0.03764566 0.06233294 0.05329797 0.04718164]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 101 at 25655 25954
# cluster cost [0.04666412 0.0534503  0.00240871 0.04723269 0.02792474 0.04648574
#  0.04317558 0.06628131 0.04919787 0.04983932]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 295
# cluster 2
#
# ========segment 102 at 25950 26249
# cluster cost [0.07214884 0.07470541 0.06809534 0.00209059 0.04183793 0.07420255
#  0.07230659 0.08430402 0.07684981 0.06847625]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 185
# cluster 3
#
# ========segment 103 at 26135 26434
# cluster cost [0.04045179 0.05093917 0.03773957 0.0405942  0.00107649 0.04062464
#  0.03430312 0.06627174 0.06205744 0.04800129]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 187
# cluster 4
#
# ========segment 104 at 26322 26621
# cluster cost [0.0535922  0.06074255 0.00201478 0.05765304 0.03134797 0.04975992
#  0.05216704 0.07084533 0.06098671 0.05571767]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 235
# cluster 2
#
# ========segment 105 at 26557 26856
# cluster cost [0.06716538 0.07352846 0.05449837 0.06221987 0.03064883 0.03187013
#  0.00281808 0.09103862 0.09182657 0.06875038]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 217
# cluster 6
#
# ========segment 106 at 26774 27073
# cluster cost [0.08116171 0.08430261 0.06197408 0.00161636 0.03074061 0.05916722
#  0.06125763 0.07929062 0.09289912 0.06576528]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 225
# cluster 3
#
# ========segment 107 at 26999 27298
# cluster cost [0.04103436 0.04919    0.04082604 0.04083975 0.00074792 0.04111926
#  0.04004125 0.06321523 0.06556146 0.05314027]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 108 at 27179 27478
# cluster cost [0.00217599 0.04717067 0.04819169 0.05689084 0.03314359 0.05543261
#  0.06100875 0.05961795 0.04975621 0.05190311]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 0
#
# ========segment 109 at 27459 27758
# cluster cost [0.04747149 0.04961143 0.04734108 0.05617032 0.03509292 0.05176073
#  0.06105704 0.04645785 0.00209259 0.04122431]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 257
# cluster 8
#
# ========segment 110 at 27716 28015
# cluster cost [0.04621317 0.05197949 0.00196981 0.05190383 0.03063653 0.04516746
#  0.04569963 0.06215752 0.04899758 0.05091572]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 2
#
# ========segment 111 at 28003 28302
# cluster cost [0.04674601 0.05198888 0.00235897 0.05202221 0.03185456 0.04306483
#  0.04536502 0.06066698 0.04999568 0.05208785]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 299
# cluster 2
#
# ========segment 112 at 28302 28601
# cluster cost [0.06344373 0.06552725 0.05428575 0.05951377 0.03321899 0.02190485
#  0.00165035 0.07674479 0.07652745 0.05025617]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 233
# cluster 6
#
# ========segment 113 at 28535 28834
# cluster cost [0.04374905 0.04393915 0.0363124  0.04129346 0.02084494 0.01593583
#  0.00160367 0.06178164 0.05233604 0.04067505]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 6
#
# ========segment 114 at 28831 29130
# cluster cost [0.05135114 0.05622496 0.04053337 0.04655276 0.02323933 0.02398728
#  0.00199919 0.07779081 0.06573652 0.05687827]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 6
#
# ========segment 115 at 29118 29417
# cluster cost [0.05412612 0.05829906 0.04367116 0.04760037 0.02532701 0.01981455
#  0.00144651 0.07418168 0.06593586 0.04737023]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 280
# cluster 6
#
# ========segment 116 at 29398 29697
# cluster cost [0.07657741 0.08286283 0.06549038 0.00315022 0.04040615 0.0708936
#  0.06851941 0.08580233 0.08166401 0.0673624 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 3
#
# ========segment 117 at 29627 29926
# cluster cost [0.04410285 0.05464132 0.03993151 0.04192025 0.00169844 0.04623039
#  0.03843381 0.06895443 0.06274981 0.04960051]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 180
# cluster 4
#
# ========segment 118 at 29807 30106
# cluster cost [0.05963639 0.06829168 0.00372703 0.06383878 0.03723738 0.05930331
#  0.06064076 0.07627213 0.06006814 0.05739123]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 236
# cluster 2
#
# ========segment 119 at 30043 30342
# cluster cost [0.06045715 0.06679465 0.0488272  0.05580115 0.02965183 0.03061715
#  0.00439247 0.0863797  0.07087973 0.0524775 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 243
# cluster 6
#
# ========segment 120 at 30286 30585
# cluster cost [0.06572443 0.07721951 0.05259281 0.00456303 0.03236057 0.06086249
#  0.05526439 0.08406986 0.07341984 0.05660082]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 248
# cluster 3
#
# ========segment 121 at 30534 30833
# cluster cost [0.05469347 0.06783764 0.04471358 0.04604959 0.00386057 0.05030941
#  0.03782565 0.08102592 0.07835884 0.05884073]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 182
# cluster 4
#
# ========segment 122 at 30716 31015
# cluster cost [0.05469438 0.06304222 0.0030178  0.05487424 0.02920992 0.054261
#  0.0542759  0.07385634 0.06352687 0.05484224]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 233
# cluster 2
#
# ========segment 123 at 30949 31248
# cluster cost [0.04324927 0.05151565 0.00212013 0.04358414 0.0237815  0.0458555
#  0.04120243 0.06623695 0.05017798 0.04805996]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 286
# cluster 2
#
# ========segment 124 at 31235 31534
# cluster cost [0.04452581 0.05146709 0.00228988 0.05004832 0.03127942 0.04955521
#  0.0490894  0.05792817 0.04437185 0.0438105 ]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 283
# cluster 2
#
# ========segment 125 at 31518 31817
# cluster cost [0.04599146 0.05295308 0.001916   0.05203774 0.03312108 0.04928108
#  0.0493567  0.05910676 0.04249553 0.04620784]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 2
#
# ========segment 126 at 31806 32105
# cluster cost [0.04419648 0.05081246 0.00172712 0.04938542 0.02773095 0.04153218
#  0.04077541 0.06237637 0.05002597 0.04869519]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 292
# cluster 2
#
# ========segment 127 at 32098 32397
# cluster cost [0.06762873 0.07240761 0.05541521 0.06112828 0.03232997 0.02779873
#  0.0012874  0.09043396 0.08388602 0.05919513]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 230
# cluster 6
#
# ========segment 128 at 32328 32627
# cluster cost [0.07535953 0.08377264 0.06434174 0.0040894  0.04386952 0.07035012
#  0.07019913 0.08763748 0.08242577 0.06982347]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 249
# cluster 3
#
# ========segment 129 at 32577 32876
# cluster cost [0.04341684 0.05314886 0.03934676 0.04184498 0.00088832 0.0379831
#  0.03342733 0.06902538 0.06917833 0.05496708]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 186
# cluster 4
#
# ========segment 130 at 32763 33062
# cluster cost [0.05579409 0.06254177 0.00137714 0.06059955 0.03536115 0.05256159
#  0.05416151 0.07176982 0.06014318 0.05870562]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 243
# cluster 2
#
# ========segment 131 at 33006 33305
# cluster cost [0.06898283 0.07343361 0.05827292 0.0636199  0.0336456  0.02543713
#  0.00103376 0.08860832 0.08831514 0.05998898]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 225
# cluster 6
#
# ========segment 132 at 33231 33530
# cluster cost [0.04954902 0.0528029  0.04280531 0.0439149  0.02125465 0.0246413
#  0.00196498 0.07183673 0.06278116 0.05028182]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 276
# cluster 6
#
# ========segment 133 at 33507 33806
# cluster cost [0.05847118 0.05504683 0.05376302 0.05839077 0.03980869 0.0306605
#  0.04857087 0.06862784 0.05496835 0.00550669]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 296
# cluster 9
#
# ========segment 134 at 33803 34102
# cluster cost [0.04575107 0.04247274 0.04291065 0.04973056 0.0305865  0.02028441
#  0.03938239 0.05487785 0.04220577 0.00265625]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 288
# cluster 9
#
# ========segment 135 at 34091 34390
# cluster cost [0.04425654 0.04476895 0.03879314 0.0452748  0.02399574 0.01808022
#  0.00244198 0.06076018 0.05122117 0.03662072]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 6
#
# ========segment 136 at 34378 34677
# cluster cost [0.06551348 0.07144006 0.05953764 0.00361687 0.03658768 0.06168901
#  0.06495508 0.06779011 0.069967   0.05484947]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 244
# cluster 3
#
# ========segment 137 at 34622 34921
# cluster cost [0.03424392 0.03937072 0.04246026 0.04037081 0.00578172 0.04513998
#  0.05040523 0.05391854 0.04417991 0.04365363]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 181
# cluster 4
#
# ========segment 138 at 34803 35102
# cluster cost [0.05582747 0.05819291 0.05577841 0.06524912 0.04146103 0.06069105
#  0.07443046 0.05468093 0.00165636 0.05123619]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 247
# cluster 8
#
# ========segment 139 at 35050 35349
# cluster cost [0.05622244 0.05249072 0.0514349  0.05901599 0.03565618 0.02387055
#  0.05092903 0.05859777 0.05140592 0.00189536]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 229
# cluster 9
#
# ========segment 140 at 35279 35578
# cluster cost [0.04207839 0.04139321 0.03694352 0.04466305 0.02316275 0.01614702
#  0.0323991  0.05186871 0.04396102 0.00319976]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 287
# cluster 9
#
# ========segment 141 at 35566 35865
# cluster cost [0.05311776 0.05035623 0.05119278 0.05856671 0.03872747 0.02701469
#  0.04920258 0.05324273 0.04791296 0.00196419]
# new cluster cost for 2: 0.01564196366332176
# size chosen: 281
# cluster 9
#
# ========segment 142 at 35847 36000
# Sequence End Reached
# best prefix found 9 nan 0.0019433397295321652
# ending with prefix [8]

# %%
st.plot(st.BeatLex, time_series, result)

# %% [markdown]
# Vocabularies | Segmentation
# :-------------------------:|:-------------------------:
# <img src="images/beatlexSum1.png" width="300"/>  |   <img src="images/beatlexSum2.png" width="300"/>
# <b>Vocabularies learned by BeatLex. |  <b>Segmentation made by BeatLex.

# %% [markdown]
# ### Experiment Results
# ------
# Beatlex(ECG)      |  Beatlex(Motion)
# :-------------------------:|:-------------------------:
# <img src="images/beatlexExp1.png" width="300"/>  |   <img src="images/beatlexExp2.png" width="300"/>
# <b>Beatlex segments and labels data. |  <b>Beatlex learns vocabulary.

# %% [markdown]
# ### Cite:
# ------
# 1. Hooi, Bryan, et al. "B eat L ex: Summarizing and Forecasting Time Series with Patterns." Joint European Conference on Machine Learning and Knowledge Discovery in Databases. Springer, Cham, 2017.
#
#     <details>
#     <summary><span style="color:blue">click for BibTex...</span></summary>
#
#     ```bibtex
#     @inproceedings{hooi2017b,
#       title={B eat L ex: Summarizing and Forecasting Time Series with Patterns},
#       author={Hooi, Bryan and Liu, Shenghua and Smailagic, Asim and Faloutsos, Christos},
#       booktitle={Joint European Conference on Machine Learning and Knowledge Discovery in Databases},
#       pages={3--19},
#       year={2017},
#       organization={Springer}
#     }
#     ```
#     </details>
